# %%
l1=[1,2,3,4]
l2=[5,6,7,8]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l1=[1,2,3,4]
l2=[5,6,7,8]
print( l2*5)
# Out:
# [5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8]

# %%
 import numpy as np
arr1= np. [1,2,3,4]
arr2= np. [5,6,7,8]
print(arr1)
print(arr2)
print(arr1+arr2)
# Out:
#   Cell In[1], line 2
#     arr1= np. [1,2,3,4]
#               ^
# SyntaxError: invalid syntax
